# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/ASUS/Documents/file_anh/anh3.jpg'

# %%
# Đọc ảnh 
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=533x572>

# %%
# Chuyển từ ảnh RGB sang ảnh xám
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=533x572>

# %%
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=533x572>
# <PIL.Image.Image image mode=L size=533x572>
# <PIL.Image.Image image mode=L size=533x572>

# %%
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=533x572>
