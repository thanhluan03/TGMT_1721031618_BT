# %%
from PIL import Image

# %%
dir = 'C:/Users/ASUS/'

# %%
image_path=dir+'/anh.jpg'
print(image_path)
# Out:
# C:/Users/ASUS//anh.jpg

# %%
anh01 = Image.open(image_path)

# %%
display(anh01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x902>
